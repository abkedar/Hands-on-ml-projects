# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

# %% [markdown]
# ## This tutorial show the use of simple Regualer Expression for Web Scraping.

# %%
random.seed(datetime.datetime.now())
def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl)
    bsObj = BeautifulSoup(html)
    return bsObj.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))

# %%
links = getLinks("/wiki/Kevin_Bacon")
# Out:
# C:\Users\kd\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\kd\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Randy_Quaid
# C:\Users\kd\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\kd\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# /wiki/The_Adventures_of_Pluto_Nash
# /wiki/Peter_Boyle
# /wiki/The_Man_Who_Could_Talk_to_Kids
# /wiki/Scott_Jacoby_(actor)
# /wiki/Robert_Vaughn
# /wiki/International_Standard_Book_Number
# /wiki/Kunrei-shiki_romanization
# /wiki/Stone_Bridge_Press
# /wiki/Consortium_Book_Sales_and_Distribution
# /wiki/Black_Dog_%26_Leventhal_Publishers
# /wiki/T%C3%A9l%C3%A9_7_Jours
# /wiki/Waldstadion_(Frankfurt)
# /wiki/Kasabian
# /wiki/B-side
# /wiki/Music_of_Guyana
# /wiki/Trinidad_and_Tobago
# /wiki/United_States
# /wiki/History_of_the_Internet
# /wiki/CompuServe
# /wiki/Control_Data_Corporation
# /wiki/International_Standard_Book_Number
# /wiki/ISO/IEC_5218
# /wiki/ISO_6438
# /wiki/EBCDIC_871
# /wiki/ZX_Spectrum_character_set
# /wiki/EBCDIC_1147
# /wiki/Code_page_1018
# /wiki/EBCDIC_9067
# /wiki/Code_page_943
# /wiki/Code_page_300
# /wiki/MSX_character_set
# /wiki/Colon_(punctuation)
# /wiki/File_Transfer_Protocol
# /wiki/Transmission_Control_Protocol
# /wiki/Session_Initiation_Protocol
# /wiki/Jonathan_Rosenberg_(SIP_author)
# /wiki/Request_for_Comments
# /wiki/University_of_California,_Los_Angeles
# /wiki/Daily_Bruin
# /wiki/Ernest_Carroll_Moore
# /wiki/Kate_Gordon_Moore
# /wiki/Attention_span
# /wiki/Time
# /wiki/Schema_for_horizontal_dials
# /wiki/Babylonian_hours
# /wiki/Second
# /wiki/Solar_calendar
# /wiki/Geology
# /wiki/Geophysical_survey
# /wiki/Crystallography
# /wiki/Felix_Bloch
# /wiki/Robert_R._Wilson
# /wiki/Isidor_Isaac_Rabi
# /wiki/Georg_Bednorz
# /wiki/David_J._Wineland
# /wiki/Norman_Hackerman
# /wiki/B._F._Skinner
# /wiki/Edwin_N._Lightfoot
# /wiki/Henry_Stommel
# /wiki/Christopher_Hooley
# /wiki/Albert_Ingham
# /wiki/SNAC
# /wiki/Historical_record
# /wiki/Invention_of_writing
# /wiki/Luwian_hieroglyphs
# /wiki/Vatteluttu_alphabet
# /wiki/Medieval_runes
# /wiki/Phoenician_alphabet
# /wiki/Teth
# /wiki/Thuluth
# /wiki/Arabic-based_creole_languages
# /wiki/English_language
# /wiki/Passive_voice
# /wiki/Prepositional_phrase
# /wiki/Syntactic_category
# /wiki/Parts_of_speech
# /wiki/Gerundive
# /wiki/Exceptional_case-marking
# /wiki/Anticausative_verb
# /wiki/Modal_verb
# /wiki/Verb
# /wiki/Measure_word
# /wiki/Copula_(linguistics)
# /wiki/Subject_(grammar)
# /wiki/Pluractionality
# /wiki/Classifier_(linguistics)
# /wiki/Verb
# /wiki/Tigrinya_verbs
# /wiki/Consonant
# /wiki/Voiceless_alveolar_fricative#Voiceless_alveolar_sibilant
# /wiki/Scouse
# /wiki/Sussex_dialect
# /wiki/Hastings
# /wiki/High_Weald_Area_of_Outstanding_Natural_Beauty
# /wiki/Greensand_Ridge
# /wiki/National_Cycle_Route_21
# /wiki/Pevensey
# /wiki/Blackham
# /wiki/Bolebroke_Castle
# /wiki/National_Heritage_List_for_England
# /wiki/England
# /wiki/Suffolk
# /wiki/Ipswich_Town_F.C.
# /wiki/England
# /wiki/Adrian_Lyne
# /wiki/Jeremy_Irons
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Information_science
# /wiki/Charles_Babbage
# /wiki/Charles_Manby
# /wiki/Saint-Servan
# /wiki/Little_Sisters_of_the_Poor
# /wiki/Salesians_of_Don_Bosco
# /wiki/Missionaries_of_the_Precious_Blood
# /wiki/Congregation_of_St._Basil
# /wiki/Ronald_Peter_Fabbro
# /wiki/St._Charles_College_(Sudbury)
# /wiki/Greater_Sudbury
# /wiki/Tomson_Highway
# /wiki/The_(Post)_Mistress
# /wiki/Northern_Ontario
# /wiki/Nipissing_(electoral_district)
# /wiki/Edmond_Lapierre
# /wiki/Member_of_Provincial_Parliament_(Ontario)
# /wiki/Legislative_Assembly_of_Ontario
# /wiki/3rd_Parliament_of_Ontario
# /wiki/Progressive_Conservative_Party_of_Ontario
# /wiki/Pauper_Party_of_Ontario
# /wiki/W._A._C._Bennett
# /wiki/Philip_Gaglardi
# /wiki/Eric_Charles_Fitzgerald_Martin
# /wiki/Vancouver-Burrard
# /wiki/Burnaby_North
# /wiki/Surrey-Whalley
# /wiki/Bruce_Ralston
# /wiki/Selina_Robinson
# /wiki/Bowinn_Ma
# /wiki/Engineering_Undergraduate_Society_of_the_University_of_British_Columbia
# /wiki/Robson_Square
# /wiki/Sinclair_Centre
# /wiki/British_Columbia
# /wiki/Confidence_and_supply
# /wiki/Mixed-member_proportional
# /wiki/Independence_of_Smith-dominated_alternatives
# /wiki/Plurality_criterion
# /wiki/Reversal_symmetry
# /wiki/Plurality_voting_system
# /wiki/Labour_Party_(UK)
# /wiki/Trade_Union_and_Labour_Party_Liaison_Organisation
# /wiki/Harold_Wilson
# /wiki/Political_status_of_Nagorno-Karabakh
# /wiki/David_Atkinson_(politician)
# /wiki/British_people
# /wiki/Languages_of_the_United_Kingdom
# /wiki/Cornish_language
# /wiki/Brittonic_languages
# /wiki/Common_Brittonic#Pritenic
# /wiki/Voiced_dental_and_alveolar_stops#Alveolar
# /wiki/Nochiya_tribe
# /wiki/Soran_District
# /wiki/Mahmoudiyah,_Iraq
# /wiki/Karkh
# /wiki/Zayouna
# /wiki/Arab_Jibor
# /wiki/Al-Amin_al-Thaniyah
# /wiki/Al-Jadriya
# /wiki/Arab_Jibor
# /wiki/Raghiba_Khatoun
# /wiki/Neighbourhoods_of_Baghdad
# /wiki/Al-Saydiya
# /wiki/Mansour_neighbourhood
# /wiki/Al-Jadriya
# /wiki/Al_Rashid,_Baghdad
# /wiki/New_Baghdad
# /wiki/Sadr_City
# /wiki/Mansour_district
# /wiki/Al-Jihad_(Baghdad)
# /wiki/Yarmouk,_Baghdad
# /wiki/List_of_hospitals_in_Iraq
# /wiki/Samarra
# /wiki/Al-Shirqat_District
# /wiki/Ba%27quba
# /wiki/Penjwin_District
# /wiki/Dekon
# /wiki/Kalar_District
# /wiki/Qaradagh_District
# /wiki/Central_Kurdish_language
# /wiki/Laki_language
# /wiki/Sorani_(language)
# /wiki/Integrated_Authority_File
# /wiki/Wayback_Machine
# /wiki/Lists_of_Internet_Archive%27s_collections
# /wiki/Internet_Archive#Text_collection
# /wiki/Biodiversity_Heritage_Library
# /wiki/Society_for_the_History_of_Natural_History#Medals_and_prizes
# /wiki/William_T._Stearn
# /wiki/Commander_of_the_Order_of_the_British_Empire
# /wiki/Royal_Guelphic_Order
# /wiki/List_of_revocations_of_appointments_to_orders_and_awarded_decorations_and_medals_of_the_United_Kingdom
# /wiki/The_London_Gazette
# /wiki/Plough
# /wiki/Sowing
# /wiki/Sow_(disambiguation)
# /wiki/Show_Low_Regional_Airport
# /wiki/Federal_Aviation_Administration
# /wiki/Hand_luggage
# /wiki/Buy_on_board
# /wiki/European_Common_Aviation_Area
# /wiki/Airline_hub
# /wiki/Immigration
# /wiki/United_Kingdom
# /wiki/Claim_of_Right_Act_1689
# /wiki/Statutory_instrument_(UK)
# /wiki/List_of_MPs_elected_in_the_United_Kingdom_general_election,_2015
# /wiki/Conservative_Party_(UK)
# /wiki/Klemens_von_Metternich
# /wiki/Joseph_Radetzky_von_Radetz
# /wiki/International_Standard_Book_Number
# /wiki/Requirements_engineering
# /wiki/QR_code
# /wiki/ISO/IEC_8859-12
# /wiki/Knowledge_Discovery_Metamodel
# /wiki/COBOL
# /wiki/ISO_15919
# /wiki/Anusvara
# /wiki/Hook_(diacritic)
# /wiki/Q
# /wiki/Letter_(alphabet)
# /wiki/Hebrew_alphabet
# /wiki/Mem
# /wiki/Semitic_root
# /wiki/Root_(linguistics)
# /wiki/Frequentative#Latin
# /wiki/Exceptional_case-marking
# /wiki/Subject_pronoun
# /wiki/Object_pronoun
# /wiki/Mass_noun
# /wiki/Agreement_(linguistics)
# /wiki/Possessive_adjective
# /wiki/Mandarin_Chinese
# /wiki/Homophone
# /wiki/Four_candles
# /wiki/George_Street,_Oxford
# /wiki/Hythe_Bridge_Street
# /wiki/Oxford_University_Press
# /wiki/Department_of_Computer_Science,_University_of_Oxford
# /wiki/Mansfield_College,_Oxford
# /wiki/Diana_Walford
# /wiki/Farhan_Nizami
# /wiki/Janet_Royall,_Baroness_Royall_of_Blaisdon
# /wiki/Beverley_Hughes
# /wiki/Patricia_Scotland
# /wiki/Jim_Murphy
# /wiki/Brian_Simon
# /wiki/Institute_of_Education
# /wiki/University_College_London
# /wiki/University_of_Derby
# /wiki/University_of_West_London
# /wiki/Havering_Sixth_Form_College
# /wiki/GCSE
# /wiki/City_and_Guilds_of_London_Institute#Licentiateship_(LCGI)
# /wiki/Engineering_technologist
# /wiki/IMechE
# /wiki/Marque
# /wiki/National_Center_for_Preservation_Technology_and_Training
# /wiki/North_American_Society_for_Oceanic_History
# /wiki/Ebenezer,_Georgia
# /wiki/American_Legation,_Tangier
# /wiki/National_Historic_Landmark
# /wiki/National_Register_of_Historic_Places_listings_in_Colorado
# /wiki/National_Register_of_Historic_Places_listings_in_Ohio
# /wiki/National_Register_of_Historic_Places_listings_in_Medina_County,_Ohio
# /wiki/National_Register_of_Historic_Places_listings_in_Clark_County,_Ohio
# /wiki/Springfield,_Ohio
# /wiki/Summit_County,_Ohio
# /wiki/Eugene_W._Chafin
# /wiki/Claude_A._Watson
# /wiki/United_States_presidential_election,_1880
# /wiki/Child_labour
# /wiki/US_State_Department
# /wiki/Bureau_of_Population,_Refugees,_and_Migration
# /wiki/Bureau_of_Democracy,_Human_Rights,_and_Labor
# /wiki/Office_of_Children%27s_Issues
# /wiki/Mike_Pompeo
# /wiki/Hillary_Clinton
# /wiki/Our_Endangered_Values
# /wiki/List_of_Governors_of_Georgia
# /wiki/Henry_Dickerson_McDaniel
# /wiki/James_Jackson_(Georgia_politician)
# /wiki/Robert_M._Charlton
# /wiki/Georgia_(U.S._state)
# /wiki/Scottish_American
# /wiki/Serbian_Americans
# /wiki/Serbian_dances
# /wiki/Television_in_Serbia
# /wiki/Food_Network
# /wiki/HGTV
# /wiki/Discovery_Science_(European_TV_channel)
# /wiki/List_of_radio_stations_in_the_United_Kingdom#Community_radio_stations
# /wiki/Restricted_Service_Licence
# /wiki/Press_Recognition_Panel
# /wiki/International_Standard_Serial_Number
# /wiki/Common_Criteria
# /wiki/Delivery_Multimedia_Integration_Framework
# /wiki/ISO-TimeML
# /wiki/MPEG-4_Part_12
# /wiki/MPEG-1_Audio_Layer_II
# /wiki/Video_CD
# /wiki/Video_High_Density
# /wiki/RCA
# /wiki/Conglomerate_(company)
# /wiki/Time_Inc.
# /wiki/Oath_Inc.
# /wiki/Weblogs,_Inc.#Autoblog
# /wiki/Time_Warner
# /wiki/Real_(TV_channel)
# /wiki/Adult_Swim
# /wiki/Titan_Maximum
# /wiki/Parody
# /wiki/Hudibras
# /wiki/William_Lilly
# /wiki/Grammar_school
# /wiki/Pulteney_Grammar_School
# /wiki/Peter_Dawson_(bass-baritone)
# /wiki/MusicBrainz
# /wiki/Rhythmbox
# /wiki/Digital_Audio_Access_Protocol
# /wiki/IOS
# /wiki/International_Standard_Book_Number
# /wiki/Audiobook
# /wiki/Dylan_Thomas
# /wiki/Caitlin_Thomas
# /wiki/Dylan_Thomas_Trail
# /wiki/Under_Milk_Wood
# /wiki/Deaths_and_Entrances
# /wiki/A_Poet_in_New_York
# /wiki/Set_Fire_to_the_Stars
# /wiki/Elijah_Wood
# /wiki/Screen_Actors_Guild
# /wiki/Charlton_Heston
# /wiki/Lionel_Hampton
# /wiki/Ray_Brown_(musician)
# /wiki/Grady_Tate
# /wiki/Grant_Green
# /wiki/Street_of_Dreams_(Grant_Green_album)
# /wiki/Larry_Young_(musician)
# /wiki/Etta_Jones
# /wiki/From_the_Heart_(Etta_Jones_album)
# /wiki/Scott_Yanow
# /wiki/CODA_(magazine)
# /wiki/Canada
# /wiki/Population_of_Canada
# /wiki/Former_colonies_and_territories_in_Canada
# /wiki/L%27Anse_aux_Meadows
# /wiki/Kimball_Village
# /wiki/Lake_Jackson_Mounds_Archaeological_State_Park
# /wiki/Folsom_tradition
# /wiki/Debitage
# /wiki/Arrow
